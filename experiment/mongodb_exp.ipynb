# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://mulpurisindhura942_db_user:ogkTnWxjBq4NAeyx@e-commerce-pydantic.rdpihft.mongodb.net/?appName=e-commerce-pydantic")

# %%
db = client["test_ecom_db"]

collection = db["products"]

print("connected to MongoDb")
# Out:
# connected to MongoDb

# %%
product = {
    "name " : "Men Casual Shirt",
    "price_usd" : 35,
    "currency" : "USD",
    "category" : "Men"
}

collection.insert_one(product)
# Out:
# InsertOneResult(ObjectId('69d92c99ff2ebe188faed703'), acknowledged=True)

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    {"name": "Kurti", "price": 999, "category": "women"},
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)

print("Multiple Products Inserted ✅")
# Out:
# Multiple Products Inserted ✅

# %%
# 🧪 🔹 CELL 6 — View All Products
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('69d6e96485945d4213966a66'), 'name ': 'Men Casual Shirt', 'price': 35, 'category': 'Men'}
# {'_id': ObjectId('69d911264634c2cfad11b5b4'), 'name ': 'Men Casual Shirt', 'price': 35, 'category': 'Men'}
# {'_id': ObjectId('69d911464634c2cfad11b5b5'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('69d911464634c2cfad11b5b6'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('69d911464634c2cfad11b5b7'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}
# {'_id': ObjectId('69d9119a4634c2cfad11b5b9'), 'name ': 'Men Casual Shirt', 'price': 35, 'category': 'Men'}
# {'_id': ObjectId('69d9119e4634c2cfad11b5ba'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('69d9119e4634c2cfad11b5bb'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('69d9119e4634c2cfad11b5bc'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}
# {'_id': ObjectId('69d92c99ff2ebe188faed703'), 'name ': 'Men Casual Shirt', 'price_usd': 35, 'currency': 'USD', 'category': 'Men'}
# {'_id': ObjectId('69d92c9cff2ebe188faed704'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('69d92c9cff2ebe188faed705'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('69d92c9cff2ebe188faed706'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %%
product = collection.find_one({"name": "Kurti"})

print(product)
# Out:
# {'_id': ObjectId('69d911464634c2cfad11b5b6'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
men_products = collection.find({"category": "kids"})

for p in men_products:
    print(p)
# Out:
# {'_id': ObjectId('69d911464634c2cfad11b5b7'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}
# {'_id': ObjectId('69d9119e4634c2cfad11b5bc'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}
# {'_id': ObjectId('69d92c9cff2ebe188faed706'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %%
collection.update_one(
    {"name": "Jeans"},
    {"$set": {"price": 1399}}
)

print("Product Updated ✅")
# Out:
# Product Updated ✅

# %%
collection.delete_one({"name": "Kids Jacket"})

print("Product Deleted ✅")

# %%
collection.delete_many({})

print("All Products Deleted ✅")

# %%
collection.drop()

print("Collection Dropped ✅")
